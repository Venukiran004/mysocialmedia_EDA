# %% [markdown]
# ![0e6631818_1507643306_training-behavior-graphic.jpg](attachment:0e6631818_1507643306_training-behavior-graphic.jpg)

# %%
import os
os.chdir(r"C:\Users\venuk\OneDrive\Desktop\instagram")
os.getcwd()
# Out:
# 'C:\\Users\\venuk\\OneDrive\\Desktop\\instagram'

# %%
import json
import pandas as pd

# %%
data=open('likes.json',"r")

# %%
loaded_data=json.loads(data.read())

# %%
loaded_data.keys()
# Out:
# dict_keys(['media_likes', 'comment_likes'])

# %%
media_likes_data=loaded_data["media_likes"]

# %%
len(media_likes_data)
# Out:
# 234

# %%
media_likes_data[2]
# Out:
# ['2020-08-17T14:00:33+00:00', 'ai_.world']

# %%
data_frame=pd.DataFrame(media_likes_data,columns=['Time', 'profile_name'])

# %%
data_frame.tail(4)
# Out:
#                           Time profile_name
# 230  2017-03-29T11:33:43+00:00  beards_love
# 231  2017-03-10T22:07:51+00:00  beards_love
# 232  2017-03-10T22:07:43+00:00  beards_love
# 233  2017-03-10T22:07:38+00:00  beards_love

# %%
len(data_frame["profile_name"].unique())
# Out:
# 96

# %%
comment_likes_data=loaded_data["comment_likes"]

# %%
len(comment_likes_data)
# Out:
# 8

# %% [markdown]
# likes=234
# profiles=96
# comments_like=8
