# %%
import os
os.chdir(r"C:\Users\venuk\OneDrive\Desktop\instagram")
os.getcwd()
# Out:
# 'C:\\Users\\venuk\\OneDrive\\Desktop\\instagram'

# %%
import json
import pandas as pd

# %%
data=open('media.json',"r")

# %%
loaded_data=json.loads(data.read())

# %%
loaded_data
# Out:
# {'photos': [{'caption': '',
#    'taken_at': '2020-01-31T18:01:55+00:00',
#    'path': 'photos/202001/7b1009436da3db93c9594e9569d65153.jpg'},
#   {'caption': '',
#    'taken_at': '2020-01-18T12:07:57+00:00',
#    'path': 'photos/202001/1115e4628915f7774115b07784fd2982.jpg'},
#   {'caption': '',
#    'taken_at': '2020-01-10T17:07:29+00:00',
#    'location': 'Terminal 2 Chatrapati Shivaji Terminal Mumbai',
#    'path': 'photos/202001/5b1612e9a7a77d0965f035e99b360ad2.jpg'},
#   {'caption': '',
#    'taken_at': '2019-12-26T09:35:35+00:00',
#    'location': 'Mini Taj Mahal, Aurangabad',
#    'path': 'photos/201912/dbb60610845673e4b5304b0c9e23b3c2.jpg'},
#   {'caption': '',
#    'taken_at': '2019-11-24T15:56:43+00:00',
#    'location': 'Pune, Maharashtra',
#    'path': 'photos/201911/522d6b88b5dee83aaca1f8585953404e.jpg'},
#   {'caption': '',
#    'taken_at': '2019-11-09T10:57:46+00:00',
#    'location': 'Lonavla, Maharashtra, India',
# ...

# %%
loaded_data.keys()
# Out:
# dict_keys(['photos', 'profile', 'direct'])

# %%
col1=loaded_data["photos"]

# %%
data_fram=pd.DataFrame(col1)
data_fram
# Out:
#    caption                   taken_at  \
# 0           2020-01-31T18:01:55+00:00
# 1           2020-01-18T12:07:57+00:00
# 2           2020-01-10T17:07:29+00:00
# 3           2019-12-26T09:35:35+00:00
# 4           2019-11-24T15:56:43+00:00
# ..     ...                        ...
# 64          2017-04-22T12:28:59+00:00
# 65          2017-04-21T11:19:07+00:00
# 66          2017-04-05T10:44:20+00:00
# 67          2017-03-28T07:26:56+00:00
# 68          2017-02-25T02:50:34+00:00
#
#                                                  path  \
# 0   photos/202001/7b1009436da3db93c9594e9569d65153...
# 1   photos/202001/1115e4628915f7774115b07784fd2982...
# 2   photos/202001/5b1612e9a7a77d0965f035e99b360ad2...
# 3   photos/201912/dbb60610845673e4b5304b0c9e23b3c2...
# 4   photos/201911/522d6b88b5dee83aaca1f8585953404e...
# ..                                                ...
# 64  photos/201704/236fd727c63b90e786ea021ebfd171aa...
# 65  photos/201704/4abb81922e1cdde67a2e7c305e05b856...
# ...

# %%
data_fram["location"].value_counts()
# Out:
# Chittoor city                                                   4
# Hyderabad                                                       3
# Chittoor, Andhra Pradesh                                        2
# Munnar Hill Station                                             1
# The Forum Mall Koramangala                                      1
# Kukat pally                                                     1
# Mini Taj Mahal, Aurangabad                                      1
# Terminal 2 Chatrapati Shivaji Terminal Mumbai                   1
# Ooty                                                            1
# OotY (pine forest)                                              1
# Charminar                                                       1
# Hussain Sagar                                                   1
# Hussain Sagar, Lumbini Park, Hyderabad                          1
# Lonavla, Maharashtra, India                                     1
# ...

# %% [markdown]
# ### ####21 places

# %% [markdown]
# ### most of uploaded pics ,location is chittoor
