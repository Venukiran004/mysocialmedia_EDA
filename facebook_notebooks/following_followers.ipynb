# %%
import json 
import pandas as pd

# %%
data=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\following_and_followers\followed_pages.json")

# %%
len(data)
# Out:
# 7

# %%
data1=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\following_and_followers\followers.json")

# %%
len(data1)
# Out:
# 7

# %%
data2=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\following_and_followers\following.json")

# %%
len(data2)
# Out:
# 23

# %%
data3=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\following_and_followers\unfollowed_pages.json")

# %%
len(data3)
# Out:
# 2

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,2,2])
col1=["followed_pages","followers","following","unfollowed_pages"]
col2=[7,7,23,2]
ax.bar(col1,col2)
plt.show()
