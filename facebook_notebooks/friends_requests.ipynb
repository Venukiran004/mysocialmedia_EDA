# %% [markdown]
# ![friend-request-facebook-5a29883047c2660036e82b2c.png](attachment:friend-request-facebook-5a29883047c2660036e82b2c.png)

# %%
import os
os.chdir(r"C:\Users\venuk\OneDrive\Desktop\facebook")
os.getcwd()
# Out:
# 'C:\\Users\\venuk\\OneDrive\\Desktop\\facebook'

# %%
import json 
import pandas as pd

# %%
data=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\friends\friends.json")

# %%
len(data)
# Out:
# 886

# %%
len(data["friends"])
# Out:
# 886

# %%
received_request=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\friends\received_friend_requests.json")

# %%
received_request.keys()
# Out:
# Index(['received_requests'], dtype='object')

# %%
len(received_request["received_requests"])
# Out:
# 1

# %%
rejected_request=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\friends\rejected_friend_requests.json")

# %%
len(rejected_request)
# Out:
# 26

# %%
removed_friends=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\friends\removed_friends.json")

# %%
len(removed_friends)
# Out:
# 429

# %%
sent_friend_requests=pd.read_json(r"C:\Users\venuk\OneDrive\Desktop\facebook\friends\sent_friend_requests.json")

# %%
len(sent_friend_requests)
# Out:
# 113

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,2,2])
col1=["friends","received_friend_requests","rejected_friend_requests","removed_friends","sent_friend_requests"]
col2=[886,1,26,429,113]
ax.bar(col1,col2)
plt.show()
